# %% [markdown]
# 🧠 Migraine Symptom Dataset for Classification:

# %% [markdown]
# *📘* Description:

# %% [markdown]
# A migraine is a neurological disorder characterized by recurrent episodes of moderate to severe headache, often accompanied by symptoms such as nausea, vomiting, and sensitivity to light and sound. The headache typically presents as a throbbing or pulsating pain, usually on one side of the head, and can last from a few hours to several days and can significantly impact daily life.
#
# Dataset: [https://www.kaggle.com/datasets/gzdekzlkaya/migraine-symptom-dataset-for-classification](https://www.kaggle.com/datasets/gzdekzlkaya/migraine-symptom-dataset-for-classification)

# %% [markdown]
# 📊 Dataset Features (Columns)
#
# Each record contains clinical attributes related to migraine symptoms:

# %% [markdown]
# | Feature        | Description |
# |----------------|-------------|
# | 🆎 **Age** | Age of the participant (numeric) |
# | ⏳ **Duration** | Duration of the migraine attack (in hours) |
# | 📅 **Frequency** | Frequency of attacks over a specific period |
# | 📍 **Location** | Pain location (1: Unilateral, 2: Bilateral, 3: Frontal, 4: Temporal) |
# | ⚡ **Character** | Nature of pain (1: Throbbing, 2: Pressing, 3: Sharp, 4: Dull) |
# | 🔥 **Intensity** | Pain severity (1: Mild → 5: Very Severe) |
# | 🤢 **Nausea** | Presence of nausea (1: Yes, 0: No) |
# | 🤮 **Vomit** | Presence of vomiting (1: Yes, 0: No) |
# | 🔊 **Phonophobia** | Sensitivity to sound (1: Yes, 0: No) |
# | 💡 **Photophobia** | Sensitivity to light (1: Yes, 0: No) |
# | 👁️ **Visual** | Visual disturbances (1: Yes, 0: No) |
# | 🖐️ **Sensory** | Numbness or tingling (1: Yes, 0: No) |
# | 🚶 **Motor** | Impaired motor function (1: Yes, 0: No) |
# | 🗣️ **Language** | Language disturbances (1: Yes, 0: No) |
# | ⚖️ **Vertigo** | Presence of dizziness (1: Yes, 0: No) |
# | 🎵 **Tinnitus** | Ringing in the ears (1: Yes, 0: No) |
# | 👂 **Hypoacusis** | Decreased hearing ability (1: Yes, 0: No) |
# | 👀 **Diplopia** | Double vision (1: Yes, 0: No) |
# | 🔍 **Defect** | Visual field defect (1: Yes, 0: No) |
# | ⚠️ **Ataxia** | Balance or coordination problems (1: Yes, 0: No) |
# | 🧠 **Conscience** | Episodes of reduced consciousness (1: Yes, 0: No) |
# | 🖐️ **Paresthesia** | Abnormal skin sensations (1: Yes, 0: No) |
# | ⚡ **DPF** | Dysfunctional physical factor (e.g., menstruation-related triggers) |
# | 🎯 **Type** | Migraine diagnosis (e.g., "Typical aura with migraine") *(Target variable)* |

# %% [markdown]
# Objectives:
#
# 1.  To study how migraine symptoms are spread among patients and how often they occur.
#
# 2. To analyze how migraine symptoms vary across different types of migraines.

# %%
# Import the pandas library for data manipulation and analysis
import pandas as pd

# Import the numpy library for numerical operations and handling arrays
import numpy as np

# Import matplotlib's pyplot module for data visualization (basic plotting)
import matplotlib.pyplot as plt

# Import seaborn library for advanced data visualization (built on top of matplotlib)
import seaborn as sns

# Import the LabelEncoder class from scikit-learn's preprocessing module
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Analysis of Migraine/migraine_symptom_classification.csv')

# %%
df #printing the dataset
# Out:
#      Age  Duration  Frequency  Location  Character  Intensity  Nausea  Vomit  \
# 0     30         1          5         1          1          2       1      0
# 1     50         3          5         1          1          3       1      1
# 2     53         2          1         1          1          2       1      1
# 3     45         3          5         1          1          3       1      0
# 4     53         1          1         1          1          2       1      0
# ..   ...       ...        ...       ...        ...        ...     ...    ...
# 395   39         1          1         1          1          3       1      1
# 396   20         3          2         1          1          3       1      0
# 397   28         3          2         1          1          3       1      0
# 398   20         3          1         1          1          3       1      0
# 399   37         1          1         1          1          3       1      1
#
# ...

# %% [markdown]
# # EDA
#
# - Distribution - histogram, bar plot, box plot
# - Trend - line chart
# - Correlation - 2- scatterplot, heatmap

# %%
df.info() #prints complete information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          400 non-null    int64
#  1   Duration     400 non-null    int64
#  2   Frequency    400 non-null    int64
#  3   Location     400 non-null    int64
#  4   Character    400 non-null    int64
#  5   Intensity    400 non-null    int64
#  6   Nausea       400 non-null    int64
#  7   Vomit        400 non-null    int64
#  8   Phonophobia  400 non-null    int64
#  9   Photophobia  400 non-null    int64
#  10  Visual       400 non-null    int64
#  11  Sensory      400 non-null    int64
#  12  Dysphasia    400 non-null    int64
#  13  Dysarthria   400 non-null    int64
#  14  Vertigo      400 non-null    int64
#  15  Tinnitus     400 non-null    int64
#  16  Hypoacusis   400 non-null    int64
#  17  Diplopia     400 non-null    int64
#  18  Defect       400 non-null    int64
# ...

# %%
# Returns a tuple representing the dimensions of the DataFrame:
#(number of rows, number of columns)
df.shape
# Out:
# (400, 24)

# %%
400*24
# Out:
# 9600

# %% [markdown]
# 📊 **Data Snapshot**
# ---------------------
# 🔢 Shape of DataFrame:
# - Rows: 400
# - Columns: 24
# - Total Data Cells: 9,600 (400 × 24)
#
# 🔢 Data Types:
# - int64: 23 columns
# - object: 1 column
#
# 💾 Memory Usage:
# - Approximately 75.1 KB

# %%
print(df.isnull().values.sum()) #prints total count of missing (null/NaN) values in the
#whole DataFrame.
# Out:
# 0

# %%
df2 = df.copy() #making copy of the original df to df2

# %%
df2
# Out:
#      Age  Duration  Frequency  Location  Character  Intensity  Nausea  Vomit  \
# 0     30         1          5         1          1          2       1      0
# 1     50         3          5         1          1          3       1      1
# 2     53         2          1         1          1          2       1      1
# 3     45         3          5         1          1          3       1      0
# 4     53         1          1         1          1          2       1      0
# ..   ...       ...        ...       ...        ...        ...     ...    ...
# 395   39         1          1         1          1          3       1      1
# 396   20         3          2         1          1          3       1      0
# 397   28         3          2         1          1          3       1      0
# 398   20         3          1         1          1          3       1      0
# 399   37         1          1         1          1          3       1      1
#
# ...

# %%
df2.describe() #prints the summary statistics
# Out:
#               Age    Duration   Frequency    Location   Character  Intensity  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.00000
# mean    31.705000    1.610000    2.365000    0.972500    0.977500    2.47000
# std     12.139043    0.770964    1.675947    0.268186    0.277825    0.76849
# min     15.000000    1.000000    1.000000    0.000000    0.000000    0.00000
# 25%     22.000000    1.000000    1.000000    1.000000    1.000000    2.00000
# 50%     28.000000    1.000000    2.000000    1.000000    1.000000    3.00000
# 75%     40.000000    2.000000    4.000000    1.000000    1.000000    3.00000
# max     77.000000    3.000000    8.000000    2.000000    2.000000    3.00000
#
#            Nausea       Vomit  Phonophobia  Photophobia  ...  Dysarthria  \
# count  400.000000  400.000000   400.000000   400.000000  ...    400.0000
# mean     0.987500    0.322500     0.977500     0.980000  ...      0.0025
# ...

# %% [markdown]
# Mean Age is 31
#
# Minimum Age is 15
#
# Max Age is 77

# %%
# Convert categorical 'Type' column to numeric values
le = LabelEncoder()
df2["Type"] = le.fit_transform(df2["Type"])  # Assign unique numeric values to each migraine type

# %%
df2
# Out:
#      Age  Duration  Frequency  Location  Character  Intensity  Nausea  Vomit  \
# 0     30         1          5         1          1          2       1      0
# 1     50         3          5         1          1          3       1      1
# 2     53         2          1         1          1          2       1      1
# 3     45         3          5         1          1          3       1      0
# 4     53         1          1         1          1          2       1      0
# ..   ...       ...        ...       ...        ...        ...     ...    ...
# 395   39         1          1         1          1          3       1      1
# 396   20         3          2         1          1          3       1      0
# 397   28         3          2         1          1          3       1      0
# 398   20         3          1         1          1          3       1      0
# 399   37         1          1         1          1          3       1      1
#
# ...

# %%
# Plotting the distribution of numerical features
plt.figure(figsize=(20, 15)) #creates a new figure of 20inches wide by 15inches tall
df.hist(bins=30, figsize=(20, 15), layout=(5, 5))  # 5x5 = 25 slots, fits 23 plots
plt.tight_layout() #adjusts spacing between subplots to prevent overlapin eachother
plt.show() #displays the final figure containing all histograms

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of demographic columns to analyze
demographic_cols = ['Age', 'Location', 'Character', 'Intensity', 'Duration']

# Loop through each column in the demographic columns list
for col in demographic_cols:
    # Create a new figure with a specific size for each plot
    plt.figure(figsize=(6,4))

    # Plot a histogram with a KDE (Kernel Density Estimate) curve for the current column
    sns.histplot(df2[col], kde=True, color='skyblue', edgecolor='black')

    # Set the title of the plot to show which column is being visualized
    plt.title(f'Distribution of {col}')

    # Label the x-axis with the column name
    plt.xlabel(col)

    # Label the y-axis as 'Count' to indicate frequency of data points
    plt.ylabel('Count')

    # Display the plot
    plt.show()

# %% [markdown]
# In the above figure we can see that:
#
# --The first chart shows the distribution of ages among people in the dataset.
# Most individuals are between 15 and 30 years old, as shown by the higher bars on the left side of the graph. As age increases, the number of people in each age group decreases, with very few people above 60.
#
#
# --The second chart shows that most people in the dataset have migraine pain in one main location, which is coded as "1" (Unilateral, meaning one side of the head). Very few people have pain in the other locations (Bilateral, Frontal, or Temporal).
#
#
# --The third chart shows that almost all patients in the dataset experience "throbbing" pain (coded as 1) during their migraines. Very few patients have other types of pain, such as "pressing," "sharp," or "dull."
#
#
# --The fourth displays the distribution of pain intensity on a scale from 1 (mild) to 5 (very severe), though the x-axis appears scaled from 0 to 3. Most reports cluster around higher intensity levels, with the highest count at level 3 (likely corresponding to intensity 5 in the original scale), followed by level 2 (likely intensity 4). Very few cases fall in the lower intensity range.
#
#
# --The fifth charts show that most individuals report experiencing severe pain intensity and shorter migraine durations. In the above chart, pain intensity is skewed toward higher levels, with the majority of cases falling between levels 4 and 5 (represented as 2.0 to 3.0 on the x-axis). In contrast, the second chart reveals that the majority of migraine attacks last around 1 hour, with fewer people reporting durations of 2 or 3 hours.

# %%
symptom_cols = [
    'Nausea', 'Vomit', 'Phonophobia', 'Photophobia', 'Visual', 'Sensory',
    'Dysphasia', 'Dysarthria', 'Vertigo', 'Tinnitus', 'Hypoacusis', 'Diplopia',
    'Defect', 'Ataxia', 'Conscience', 'Paresthesia', 'DPF'
]

# %%
# Sum the values for each symptom column across all rows in the DataFrame
symptom_counts = df2[symptom_cols].sum()

# Sort the summed values in descending order to see the most frequent symptoms first
symptom_counts = symptom_counts.sort_values(ascending=False)

# Print the sorted counts of each symptom
print(symptom_counts)
# Out:
# Visual         595
# Nausea         395
# Photophobia    392
# Phonophobia    391
# DPF            164
# Vomit          129
# Sensory        121
# Vertigo         50
# Tinnitus        24
# Dysphasia       15
# Conscience       7
# Defect           6
# Hypoacusis       6
# Paresthesia      3
# Diplopia         2
# Dysarthria       1
# Ataxia           0
# dtype: int64

# %%
# Create a new figure with a size of 10 inches wide by 5 inches tall
plt.figure(figsize=(10, 5))

# Create a bar plot using Seaborn
# x: symptom names (categories) from symptom_counts index
# y: corresponding counts (number of patients) from symptom_counts values
# palette: color scheme 'coolwarm' for the bars
sns.barplot(x=symptom_counts.index, y=symptom_counts.values, palette='coolwarm')

# Set the title of the plot
plt.title('Common Migraine Symptoms')

# Label the y-axis to indicate it represents the number of patients
plt.ylabel('Number of Patients')

# Label the x-axis to indicate it represents symptoms
plt.xlabel('Symptom')

# Rotate x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45)

# Adjust subplot parameters to give specified padding and prevent overlap
plt.tight_layout()

# Display the final plot
plt.show()
# Out:
# <ipython-input-19-848632303>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=symptom_counts.index, y=symptom_counts.values, palette='coolwarm')

# %% [markdown]
# The above chart illustrates the most common symptoms reported by migraine patients.
# Visual disturbances are the most prevalent, affecting over 600 individuals, followed by nausea, photophobia (light sensitivity), and phonophobia (sound sensitivity), each affecting around 400 patients. Less frequent symptoms include dizziness, vomiting, sensory disturbances, and vertigo. Rare symptoms such as dysarthria, ataxia, and diplopia are reported by very few patients.
#
# This highlights that while migraines commonly impact vision and sensory perception, more severe neurological symptoms are relatively uncommon.

# %% [markdown]
# To analyze how migraine symptoms vary across different types of migraines.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Group by migraine type and compute the mean for binary symptoms
symptom_by_type = df.groupby('Type')[symptom_cols].mean()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(symptom_by_type, annot=True, cmap="coolwarm", cbar_kws={'label': 'Symptom Frequency'})
plt.title("Symptom Frequency by Migraine Type")
plt.xlabel("Symptom")
plt.ylabel("Migraine Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The above heatmap shows the frequency of different symptoms across various migraine types. Each cell represents how often a particular symptom (like nausea, visual disturbances, vertigo, etc.) occurs for each migraine type. Darker red shades indicate higher frequency, while blue shades indicate lower or zero occurrence.
#
#
# From the plot:
#
#
# Visual symptoms are highly prevalent in "Typical aura without migraine" and "Basilar-type aura".
#
#
# Common symptoms like nausea, phonophobia, and photophobia are present across almost all migraine types.
#
#
# Less common symptoms such as ataxia, diplopia, and dysarthria appear very rarely or not at all.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Bar Plot

# Convert Location to string so Seaborn treats it as categorical
df['Location'] = df['Location'].astype(str)

# Set up the figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot histogram
sns.histplot(data=df, x='Location', hue='Type', multiple='dodge')

# Labels and layout
ax.set_title('Location of Pain with Type of Migraine:', fontsize=16)
ax.set_xlabel('Location', fontsize=13)
ax.set_ylabel('Count', fontsize=13)

plt.subplots_adjust(right=0.75)
plt.show()

# %% [markdown]
# The bar chart shows how pain location varies with different migraine types. Most people with "Typical aura with migraine" and "Migraine without aura" experience unilateral pain, making it the most common pattern. Other migraine types like "Basilar-type aura" and "Hemiplegic migraines" also mostly involve unilateral pain but are less frequent.
#
# "Typical aura without migraine" stands out with more cases of frontal and temporal pain, showing greater variation.
#
# Overall, unilateral pain is the most dominant location, especially in migraines with aura, while rarer types show more diverse pain locations.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr, chi2_contingency, kruskal
import numpy as np

# Select columns for analysis
cols = ['Age', 'Duration', 'Frequency', 'Location', 'Character', 'Intensity']

# Convert 'Location' and 'Character' to categorical if they aren't
df2['Location'] = df2['Location'].astype('category')
df2['Character'] = df2['Character'].astype('category')

# 1️⃣ Correlation Heatmap (Numeric only: Age, Duration, Frequency, Pain_Intensity)
numeric_cols = ['Age', 'Duration', 'Frequency', 'Intensity']
corr_matrix = df2[numeric_cols].corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Spearman Correlation: Numeric Variables")
plt.show()

# 2️⃣ Kruskal-Wallis: Categorical (Location/Character) vs Numeric (Duration/Frequency/etc)
print("Kruskal-Wallis Test Results:\n")
for cat in ['Location', 'Character']:
    for num in ['Age', 'Duration', 'Frequency', 'Intensity']:
        groups = [group[num].dropna() for name, group in df.groupby(cat)]
        stat, p = kruskal(*groups)
        print(f"{cat} vs {num}: H={stat:.2f}, p={p:.4f}")

# 3️⃣ Chi-Square Test: Location vs Character (both categorical)
contingency_table = pd.crosstab(df2['Location'], df2['Character'])
chi2, p, dof, ex = chi2_contingency(contingency_table)
print(f"\nChi-Square Test between Location and Character:\nChi2 = {chi2:.2f}, p = {p:.4f}")
# Out:
# Kruskal-Wallis Test Results:
#
# Location vs Age: H=5.91, p=0.0520
# Location vs Duration: H=0.27, p=0.8742
# Location vs Frequency: H=0.43, p=0.8048
# Location vs Intensity: H=80.02, p=0.0000
# Character vs Age: H=5.49, p=0.0642
# Character vs Duration: H=0.48, p=0.7862
# Character vs Frequency: H=0.70, p=0.7059
# Character vs Intensity: H=81.11, p=0.0000
#
# Chi-Square Test between Location and Character:
# Chi2 = 655.28, p = 0.0000

# %% [markdown]
# Statistical analysis revealed that pain intensity varies significantly depending on both the location and character of the migraine (p < 0.0001). Additionally, a strong association exists between pain location and character (Chi2 = 655.28, p < 0.0001), suggesting that these two features are often interlinked in how migraines present.

# %%
# Import seaborn for statistical visualizations
import seaborn as sns

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Set the figure size to 10 inches wide and 6 inches tall
plt.figure(figsize=(10, 6))

# Create a box plot to show the distribution of Age across different Migraine Types
sns.boxplot(x='Type', y='Age', data=df)

# Rotate the x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45)

# Set the title of the plot
plt.title('Age Distribution by Migraine Type')

# Label the x-axis
plt.xlabel('Migraine Type')

# Label the y-axis
plt.ylabel('Age')

# Adjust layout to prevent overlapping elements
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# The boxplot shows the age distribution across different migraine types. Here's what it reveals:
#
# "Typical aura with migraine" and "Migraine without aura" have a wide age range, with patients spanning from teens to elderly. These types also include several outliers, indicating some very young or older individuals.
#
# "Basilar-type aura" has a slightly narrower spread but still includes middle-aged patients predominantly.
#
# "Sporadic" and "Familial hemiplegic migraines" mostly affect younger individuals, with compact interquartile ranges (IQRs) and lower median ages, suggesting they are more common in younger patients.
#
# "Other" migraine types have the widest spread, including both younger and older patients, and the highest median age among all.
#
# "Typical aura without migraine" shows a moderate age range, mostly in young to middle-aged adults.
#
# Summary:
#
# This plot indicates that common migraine types like those with or without aura affect a broad age range, while rarer forms, especially hemiplegic migraines, tend to occur in younger individuals.

# %% [markdown]
# ***Findings***:
#
# 1. This suggests that migraines in this dataset are most common in younger adults and less common in older age groups.
#
# 2. For most patients, migraine pain is felt on one side of the head.
#
# 3. Throbbing pain is by far the most common nature of migraine pain among the people in this study
#
# 4. Individuals are more frequently experiencing moderate to very severe pain rather than mild pain.
#
# 5.  Pain location varies with different migraine types. Overall, unilateral pain is the most dominant location, especially in migraines with aura, while rarer types show more diverse pain locations.
#
# 6. Statistical analysis revealed that pain intensity varies significantly depending on both the location and character of the migraine. Additionally, a strong association exists between pain location and nature of pain, suggesting that these two features are often interlinked in how migraines present.
#
# 7. Visual symptoms are highly prevalent in "Typical aura without migraine" and "Basilar-type aura". Common symptoms like nausea, phonophobia, and photophobia are present across almost all migraine types.
